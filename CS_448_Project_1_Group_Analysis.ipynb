# %% [markdown]
# <a href="https://colab.research.google.com/github/A-Wadhwani/CS448-Project1/blob/master/CS_448_Project_1_Group_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def createPlot(experiment, name):
  df = pd.read_csv('mru_' + name)
  df1 = pd.read_csv('lru_' + name)
  mru = df[df["mode"]=="MRU"]
  lru = df1[df1["mode"]=="MRU"]
  fault = df[df["mode"]=="default"]
  fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(30,6))
  fig.suptitle(experiment + " hits and misses")

  # Hits Plot
  ax1.plot(mru["n"],mru["hits"], label="Most Recently Used", alpha=0.7)
  ax1.plot(lru["n"],lru["hits"], 'g', label="Least Recently Used", alpha=0.7)
  ax1.plot(fault["n"],fault["hits"], label="Default", alpha=0.7)
  ax1.title.set_text(experiment + " Hits")
  ax1.set(xlabel="Size of input (n)", ylabel="Number of Hits")
  ax1.legend()
  
  # Misses Plot
  ax2.plot(mru["n"],mru["misses"], label="Most Recently Used", alpha=0.7)
  ax2.plot(lru["n"],lru["misses"], 'g', label="Least Recently Used", alpha=0.7)
  ax2.plot(fault["n"],fault["misses"], label="Default", alpha=0.7)
  ax2.title.set_text(experiment + " Misses")
  ax2.set(xlabel="Size of input (n)", ylabel="Number of Misses")
  ax2.legend()
  
  # Writes
  ax3.plot(mru["n"],mru["writes"], label="Most Recently Used", alpha=0.7)
  ax3.plot(lru["n"],lru["writes"], 'g', label="Least Recently Used", alpha=0.7)
  ax3.plot(fault["n"],fault["writes"], label="Default", alpha=0.7)
  ax3.title.set_text(experiment + " Total Writes")
  ax3.set(xlabel="Size of input (n)", ylabel=" Total Writes")
  ax3.legend()

  # Ratio
  ax4.plot(mru["n"],mru["hits"]/mru["misses"], label="Most Recently Used", alpha=0.7)
  ax4.plot(lru["n"],lru["hits"]/lru["misses"], 'g', label="Least Recently Used", alpha=0.7)
  ax4.plot(fault["n"],fault["hits"]/fault["misses"], label="Default", alpha=0.7)
  ax4.title.set_text(experiment + " Hits:Misses Ratio")
  ax4.set(xlabel="Size of input (n)", ylabel="Hits:Misses ratio")
  ax4.legend()
  fig.show()

# %%
createPlot("Create Table", "createTable.csv")

# %%
createPlot("Join Table", "joinTable.csv")

# %%
createPlot("Large Join Table", "largeJoinTable.csv")

# %%
createPlot("Select Table", "selectTable.csv")

# %%
createPlot("Update Table", "updateTable.csv")

# %%
createPlot("Delete From Table", "deleteFromTable.csv")

# %%
createPlot("Random Operations", "randomTests.csv")
